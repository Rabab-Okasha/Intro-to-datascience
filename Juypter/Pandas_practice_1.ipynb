# %% [markdown]
# print('BOOM')

# %%
# import pandas as pd
# elections = pd.read_table("C:/Users/rabab/Documents/elections.txt")

# with open("C:/Users/rabab/Documents/elections.txt", "r") as file:  # Windows
#     elections = file.read()
#     print(elections)
# Out:
# Year,State,Candidate,Party,Votes,Percentage
# 2020,California,Joe Biden,Democratic,11110250,63.5
# 2020,Texas,Donald Trump,Republican,5258126,52.1
# 2020,Florida,Donald Trump,Republican,5668731,51.2
# 2016,California,Hillary Clinton,Democratic,8753788,61.7
# 2016,Texas,Donald Trump,Republican,4685047,52.2
# 2016,Florida,Donald Trump,Republican,4617886,49.1

# %% [markdown]
# elections.shape

# %%
import pandas as pd
elections = pd.read_csv("Documents/elections.txt")
print(type(elections))  # Should output: <class 'pandas.core.frame.DataFrame'>
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 2
#       1 import pandas as pd
# ----> 2 elections = pd.read_csv("Documents/elections.txt")
#       3 print(type(elections))  # Should output: <class 'pandas.core.frame.DataFrame'>
#
# ...

# %%
import os
print(os.getcwd())  # Prints the current working directory
# Out:
# C:\Users\rabab\Downloads

# %%
import pandas as pd
elections = pd.read_csv("Downloads/elections.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[24], line 2
#       1 import pandas as pd
# ----> 2 elections = pd.read_csv("Downloads/elections.txt")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
elections = pd.read_csv("elections.txt")
elections
# Out:
#    Year       State        Candidate       Party     Votes  Percentage
# 0  2020  California        Joe Biden  Democratic  11110250        63.5
# 1  2020       Texas     Donald Trump  Republican   5258126        52.1
# 2  2020     Florida     Donald Trump  Republican   5668731        51.2
# 3  2016  California  Hillary Clinton  Democratic   8753788        61.7
# 4  2016       Texas     Donald Trump  Republican   4685047        52.2
# 5  2016     Florida     Donald Trump  Republican   4617886        49.1

# %%
import os
print(os.getcwd())  # Prints the current working directory
# Out:
# C:\Users\rabab\Downloads

# %%
elections.shape
# Out:
# (6, 6)

# %%
elections.size
# Out:
# 36

# %%
elections.describe()
# Out:
#              Year         Votes  Percentage
# count     6.00000  6.000000e+00    6.000000
# mean   2018.00000  6.682305e+06   54.966667
# std       2.19089  2.653459e+06    6.043730
# min    2016.00000  4.617886e+06   49.100000
# 25%    2016.00000  4.828317e+06   51.425000
# 50%    2018.00000  5.463428e+06   52.150000
# 75%    2020.00000  7.982524e+06   59.325000
# max    2020.00000  1.111025e+07   63.500000

# %%
elections.head()
# Out:
#    Year       State        Candidate       Party     Votes  Percentage
# 0  2020  California        Joe Biden  Democratic  11110250        63.5
# 1  2020       Texas     Donald Trump  Republican   5258126        52.1
# 2  2020     Florida     Donald Trump  Republican   5668731        51.2
# 3  2016  California  Hillary Clinton  Democratic   8753788        61.7
# 4  2016       Texas     Donald Trump  Republican   4685047        52.2

# %%
elections.head(3)
# Out:
#    Year       State     Candidate       Party     Votes  Percentage
# 0  2020  California     Joe Biden  Democratic  11110250        63.5
# 1  2020       Texas  Donald Trump  Republican   5258126        52.1
# 2  2020     Florida  Donald Trump  Republican   5668731        51.2

# %%
elections.tail()
# Out:
#    Year       State        Candidate       Party    Votes  Percentage
# 1  2020       Texas     Donald Trump  Republican  5258126        52.1
# 2  2020     Florida     Donald Trump  Republican  5668731        51.2
# 3  2016  California  Hillary Clinton  Democratic  8753788        61.7
# 4  2016       Texas     Donald Trump  Republican  4685047        52.2
# 5  2016     Florida     Donald Trump  Republican  4617886        49.1

# %%
elections.tail(3)
# Out:
#    Year       State        Candidate       Party    Votes  Percentage
# 3  2016  California  Hillary Clinton  Democratic  8753788        61.7
# 4  2016       Texas     Donald Trump  Republican  4685047        52.2
# 5  2016     Florida     Donald Trump  Republican  4617886        49.1

# %%
elections = pd.read_csv("elections.txt", index_col = 'Year')

# %%
elections_party_index = pd.set_index('Party')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 elections_party_index = pd.set_index('Party')
#
# AttributeError: module 'pandas' has no attribute 'set_index'

# %%
elections
# Out:
#            State        Candidate       Party     Votes  Percentage
# Year
# 2020  California        Joe Biden  Democratic  11110250        63.5
# 2020       Texas     Donald Trump  Republican   5258126        52.1
# 2020     Florida     Donald Trump  Republican   5668731        51.2
# 2016  California  Hillary Clinton  Democratic   8753788        61.7
# 2016       Texas     Donald Trump  Republican   4685047        52.2
# 2016     Florida     Donald Trump  Republican   4617886        49.1

# %%
elections = pd.read_csv("elections.txt")
elections
# Out:
#    Year       State        Candidate       Party     Votes  Percentage
# 0  2020  California        Joe Biden  Democratic  11110250        63.5
# 1  2020       Texas     Donald Trump  Republican   5258126        52.1
# 2  2020     Florida     Donald Trump  Republican   5668731        51.2
# 3  2016  California  Hillary Clinton  Democratic   8753788        61.7
# 4  2016       Texas     Donald Trump  Republican   4685047        52.2
# 5  2016     Florida     Donald Trump  Republican   4617886        49.1

# %%
elections_party_index = elections.set_index('Party')
elections
# Out:
#    Year       State        Candidate       Party     Votes  Percentage
# 0  2020  California        Joe Biden  Democratic  11110250        63.5
# 1  2020       Texas     Donald Trump  Republican   5258126        52.1
# 2  2020     Florida     Donald Trump  Republican   5668731        51.2
# 3  2016  California  Hillary Clinton  Democratic   8753788        61.7
# 4  2016       Texas     Donald Trump  Republican   4685047        52.2
# 5  2016     Florida     Donald Trump  Republican   4617886        49.1

# %%
elections.set_index('State', inplace = True)
elections
# Out:
#                   Candidate       Party     Votes  Percentage
# State
# California        Joe Biden  Democratic  11110250        63.5
# Texas          Donald Trump  Republican   5258126        52.1
# Florida        Donald Trump  Republican   5668731        51.2
# California  Hillary Clinton  Democratic   8753788        61.7
# Texas          Donald Trump  Republican   4685047        52.2
# Florida        Donald Trump  Republican   4617886        49.1

# %%
elections
# Out:
#                   Candidate       Party     Votes  Percentage
# State
# California        Joe Biden  Democratic  11110250        63.5
# Texas          Donald Trump  Republican   5258126        52.1
# Florida        Donald Trump  Republican   5668731        51.2
# California  Hillary Clinton  Democratic   8753788        61.7
# Texas          Donald Trump  Republican   4685047        52.2
# Florida        Donald Trump  Republican   4617886        49.1

# %%
elections = pd.read_csv("elections.txt")
elections
# Out:
#    Year       State        Candidate       Party     Votes  Percentage
# 0  2020  California        Joe Biden  Democratic  11110250        63.5
# 1  2020       Texas     Donald Trump  Republican   5258126        52.1
# 2  2020     Florida     Donald Trump  Republican   5668731        51.2
# 3  2016  California  Hillary Clinton  Democratic   8753788        61.7
# 4  2016       Texas     Donald Trump  Republican   4685047        52.2
# 5  2016     Florida     Donald Trump  Republican   4617886        49.1

# %%
elections['Year']
# Out:
# 0    2020
# 1    2020
# 2    2020
# 3    2016
# 4    2016
# 5    2016
# Name: Year, dtype: int64

# %%
elections[['Year']]
# Out:
#    Year
# 0  2020
# 1  2020
# 2  2020
# 3  2016
# 4  2016
# 5  2016

# %%
elections[['Year', 'State']]
# Out:
#    Year       State
# 0  2020  California
# 1  2020       Texas
# 2  2020     Florida
# 3  2016  California
# 4  2016       Texas
# 5  2016     Florida

# %%
thing = 'Year'
elections[thing]
# Out:
# 0    2020
# 1    2020
# 2    2020
# 3    2016
# 4    2016
# 5    2016
# Name: Year, dtype: int64

# %%
thing = ['Year']
elections[thing]
# Out:
#    Year
# 0  2020
# 1  2020
# 2  2020
# 3  2016
# 4  2016
# 5  2016

# %%
thing = ['Year', 'Candidate']
elections[thing]
# Out:
#    Year        Candidate
# 0  2020        Joe Biden
# 1  2020     Donald Trump
# 2  2020     Donald Trump
# 3  2016  Hillary Clinton
# 4  2016     Donald Trump
# 5  2016     Donald Trump

# %%
elections[0:3] #exclusive way (right endpoint is not included)
# Out:
#    Year       State     Candidate       Party     Votes  Percentage
# 0  2020  California     Joe Biden  Democratic  11110250        63.5
# 1  2020       Texas  Donald Trump  Republican   5258126        52.1
# 2  2020     Florida  Donald Trump  Republican   5668731        51.2

# %%
elections[0] # this way is used only for columns and there is no column named as 0
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 elections[0]
#
# ...

# %%
elections[1:]
# Out:
#    Year       State        Candidate       Party    Votes  Percentage
# 1  2020       Texas     Donald Trump  Republican  5258126        52.1
# 2  2020     Florida     Donald Trump  Republican  5668731        51.2
# 3  2016  California  Hillary Clinton  Democratic  8753788        61.7
# 4  2016       Texas     Donald Trump  Republican  4685047        52.2
# 5  2016     Florida     Donald Trump  Republican  4617886        49.1

# %%
#weird = pd.dataframe({1:["topdog", "botdog"], "1":["topcat", "botcat"]})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 weird = pd.dataframe({1:["topdog", "botdog"], "1":["topcat", "botcat"]})
#       2 weird
#
# AttributeError: module 'pandas' has no attribute 'dataframe'

# %%
elections
# Out:
#    Year       State        Candidate       Party     Votes  Percentage
# 0  2020  California        Joe Biden  Democratic  11110250        63.5
# 1  2020       Texas     Donald Trump  Republican   5258126        52.1
# 2  2020     Florida     Donald Trump  Republican   5668731        51.2
# 3  2016  California  Hillary Clinton  Democratic   8753788        61.7
# 4  2016       Texas     Donald Trump  Republican   4685047        52.2
# 5  2016     Florida     Donald Trump  Republican   4617886        49.1

# %%
elections['Year'] == 2020 # in series
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# 5    False
# Name: Year, dtype: bool

# %%
elections['Percentage'] + 5 # in series
# Out:
# 0    68.5
# 1    57.1
# 2    56.2
# 3    66.7
# 4    57.2
# 5    54.1
# Name: Percentage, dtype: float64

# %%
year20 = elections['Year'] == 2020
elections[year20] # in dataframe
# Out:
#    Year       State     Candidate       Party     Votes  Percentage
# 0  2020  California     Joe Biden  Democratic  11110250        63.5
# 1  2020       Texas  Donald Trump  Republican   5258126        52.1
# 2  2020     Florida  Donald Trump  Republican   5668731        51.2

# %%
elections[elections['Year'] == 2016] # best practice to put it in dataframe without using a variable
# Out:
#    Year       State        Candidate       Party    Votes  Percentage
# 3  2016  California  Hillary Clinton  Democratic  8753788        61.7
# 4  2016       Texas     Donald Trump  Republican  4685047        52.2
# 5  2016     Florida     Donald Trump  Republican  4617886        49.1

# %%
elections[elections['State'] == 'Texas']
# Out:
#    Year  State     Candidate       Party    Votes  Percentage
# 1  2020  Texas  Donald Trump  Republican  5258126        52.1
# 4  2016  Texas  Donald Trump  Republican  4685047        52.2

# %%
elections[(elections['Year'] == 2016) & (elections['Percentage'] < 60)]
# Out:
#    Year    State     Candidate       Party    Votes  Percentage
# 4  2016    Texas  Donald Trump  Republican  4685047        52.2
# 5  2016  Florida  Donald Trump  Republican  4617886        49.1

# %%
elections['Candidate'] # in series
# Out:
#          Candidate
# 0        Joe Biden
# 1     Donald Trump
# 2     Donald Trump
# 3  Hillary Clinton
# 4     Donald Trump
# 5     Donald Trump

# %%
elections.loc[:, 'Candidate']  # in series
# Out:
# 0          Joe Biden
# 1       Donald Trump
# 2       Donald Trump
# 3    Hillary Clinton
# 4       Donald Trump
# 5       Donald Trump
# Name: Candidate, dtype: object

# %%
elections.loc[: 'Candidate'] # new!!
# Out:
#    Year       State        Candidate       Party     Votes  Percentage
# 0  2020  California        Joe Biden  Democratic  11110250        63.5
# 1  2020       Texas     Donald Trump  Republican   5258126        52.1
# 2  2020     Florida     Donald Trump  Republican   5668731        51.2
# 3  2016  California  Hillary Clinton  Democratic   8753788        61.7
# 4  2016       Texas     Donald Trump  Republican   4685047        52.2
# 5  2016     Florida     Donald Trump  Republican   4617886        49.1

# %%
thing1 = [0, 2, 4]
thing2 = ['Candidate', 'Year']
elections.loc[thing1, thing2]
# Out:
#       Candidate  Year
# 0     Joe Biden  2020
# 2  Donald Trump  2020
# 4  Donald Trump  2016

# %%
elections.loc[[3, 4, 5], ['Candidate', 'Percentage']]
# Out:
#          Candidate  Percentage
# 3  Hillary Clinton        61.7
# 4     Donald Trump        52.2
# 5     Donald Trump        49.1

# %%
elections.loc[0:4, ['Party']]
# Out:
#         Party
# 0  Democratic
# 1  Republican
# 2  Republican
# 3  Democratic
# 4  Republican

# %%
elections[['Party']][0:5]
# Out:
#         Party
# 0  Democratic
# 1  Republican
# 2  Republican
# 3  Democratic
# 4  Republican

# %%
elections.loc[:, :]
# Out:
#    Year       State        Candidate       Party     Votes  Percentage
# 0  2020  California        Joe Biden  Democratic  11110250        63.5
# 1  2020       Texas     Donald Trump  Republican   5258126        52.1
# 2  2020     Florida     Donald Trump  Republican   5668731        51.2
# 3  2016  California  Hillary Clinton  Democratic   8753788        61.7
# 4  2016       Texas     Donald Trump  Republican   4685047        52.2
# 5  2016     Florida     Donald Trump  Republican   4617886        49.1

# %%
elections.loc[1, :]
# Out:
# Year                  2020
# State                Texas
# Candidate     Donald Trump
# Party           Republican
# Votes              5258126
# Percentage            52.1
# Name: 1, dtype: object

# %%
elections.loc[[1], :]
# Out:
#    Year  State     Candidate       Party    Votes  Percentage
# 1  2020  Texas  Donald Trump  Republican  5258126        52.1

# %%
elections.loc[elections[(elections['Year'] == 2016) & (elections['Percentage'] < 60)], ['Candidate', 'Party'] # ???
# Out:
#   Cell In[121], line 1
#     elections.loc[elections[(elections['Year'] == 2016) & (elections['Percentage'] < 60)], ['Candidate', 'Party']
#                                                                                                                  ^
# _IncompleteInputError: incomplete input

# %%
elections.iloc[0:3, 0:4] # exclusive (right hand side is not included)
# Out:
#    Year       State     Candidate       Party
# 0  2020  California     Joe Biden  Democratic
# 1  2020       Texas  Donald Trump  Republican
# 2  2020     Florida  Donald Trump  Republican

# %%
elections.sort_values('Percentage', ascending = False)
# Out:
#    Year       State        Candidate       Party     Votes  Percentage
# 0  2020  California        Joe Biden  Democratic  11110250        63.5
# 3  2016  California  Hillary Clinton  Democratic   8753788        61.7
# 4  2016       Texas     Donald Trump  Republican   4685047        52.2
# 1  2020       Texas     Donald Trump  Republican   5258126        52.1
# 2  2020     Florida     Donald Trump  Republican   5668731        51.2
# 5  2016     Florida     Donald Trump  Republican   4617886        49.1

# %%
elections['Party'].value_counts()
# Out:
# Party
# Republican    4
# Democratic    2
# Name: count, dtype: int64
